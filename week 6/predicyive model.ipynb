# %% [markdown]
# ## Create a notebook within which you identify a high-quality predictive model using the pre-processed data

# %%
# importing the required packages and modules
# data handling modules
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# model handling modules
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier 
from sklearn.linear_model import LogisticRegressionCV
# metrix module for model evalution 
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.svm import SVC
from sklearn.metrics import fbeta_score, make_scorer, recall_score,precision_score
import warnings
warnings.simplefilter("ignore")

np.random.seed(1)

# %% [markdown]
# ## load pre processed data

# %%
X_train = pd.read_csv('obes_train_X.csv')
y_train = pd.read_csv('obes_train_y.csv') 
X_test = pd.read_csv('obes_test_X.csv')
y_test = pd.read_csv('obes_test_y.csv')

# %%
print("X_train shape",X_train.shape)
print("y_train shape",y_train.shape)
print("X_test shape",X_test.shape)
print("y_test shape",y_test.shape)
# Out:
# X_train shape (1477, 23)
# y_train shape (1477, 1)
# X_test shape (634, 23)
# y_test shape (634, 1)

# %% [markdown]
# ## create dataframe to store all metric value of models

# %%
performance = pd.DataFrame({"model": [], "Accuracy": [], "Precision": [], "Recall": [], "F1": []})

# %% [markdown]
# ## Logistic model

# %%
log_reg_model = LogisticRegressionCV(max_iter=2000,solver='newton-cg')
lrCVfit= log_reg_model.fit(X_train,np.ravel(y_train))
lr_y_pre=lrCVfit.predict(X_test)

# %%
# model_preds = dtRSCV.predict(X_test)
# print(len(model_preds))
c_matrix = confusion_matrix(y_test, lr_y_pre)
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]
performance = pd.concat([performance, pd.DataFrame({'model':"LR", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])

# %% [markdown]
# ## logistic regression CV with  Randomized Search & Grid Search

# %%
# %%time
# parameters for grid & random search Cv for Logistic
score_measure =   make_scorer(recall_score, average='micro')
kfolds = 3

param = {
    'solver'  : ['liblinear','newton-cg', 'lbfgs'],
}

# call Logistic regression 
LR=LogisticRegressionCV()

# grid Search CV call 
gridCV=GridSearchCV(estimator = LR, param_grid=param, cv=kfolds,
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True,error_score='raise')
gridCV.fit(X_train,np.ravel( y_train))

# random Search CV call

randomCV=RandomizedSearchCV(estimator =LR, param_distributions=param, cv=kfolds,
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True,error_score='raise')

randomCV.fit(X_train,np.ravel(y_train))

print("**************Logistic Grid Search CV********************")
print(f"The best {score_measure} score is {gridCV.best_score_}")
print(f"with parameters: {gridCV.best_params_}")

print(f"Best Estimators in grid cv :{gridCV.best_estimator_}")


print("**************Logistic Random Search CV********************")
print(f"The best {score_measure} score is {randomCV.best_score_}")
print(f"with parameters: {randomCV.best_params_}")

print(f"Best Estimators in grid cv :{randomCV.best_estimator_}")
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(
# **************Logistic Grid Search CV********************
# The best make_scorer(recall_score, average=micro) score is 0.9485355959036265
# with parameters: {'solver': 'newton-cg'}
# Best Estimators in grid cv :LogisticRegressionCV(solver='newton-cg')
# **************Logistic Random Search CV********************
# The best make_scorer(recall_score, average=micro) score is 0.9485355959036265
# with parameters: {'solver': 'newton-cg'}
# Best Estimators in grid cv :LogisticRegressionCV(solver='newton-cg')
# Wall time: 2min 43s
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\optimize.py:210: ConvergenceWarning: newton-cg failed to converge. Increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# # Decision tree

# %%
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
y_pred_dtree=dtree.predict(X_test)

# %%
c_matrix = confusion_matrix(y_test, y_pred_dtree)
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]
performance = pd.concat([performance, pd.DataFrame({'model':"dtree", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])

# %% [markdown]
# ## Decision tree Randomized search

# %%
score_measure =   make_scorer(recall_score, average='micro')
kfolds = 5

param_grid = {
    'min_samples_split': np.arange(30,36),  
    'min_samples_leaf': np.arange(6,12),
    #'min_impurity_decrease': np.arange(0.0048, 0.0054, 0.0001),
    #'max_leaf_nodes': np.arange(162,168), 
    'max_depth': np.arange(15,21), 
    'criterion': ['entropy'],
    
}

dtree = DecisionTreeClassifier()
rand_search = RandomizedSearchCV(estimator = dtree, param_distributions=param_grid, cv=kfolds, n_iter=500,
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True,error_score='raise')

dtRSCV= rand_search.fit(X_train, y_train)

print(f"The best {score_measure} score is {rand_search.best_score_}")
print(f"... with parameters: {rand_search.best_params_}")

bestRecallTree = rand_search.best_estimator_
# Out:
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 216 is smaller than n_iter=500. Running 216 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# The best make_scorer(recall_score, average=micro) score is 0.9092693540998626
# ... with parameters: {'min_samples_split': 30, 'min_samples_leaf': 6, 'max_depth': 17, 'criterion': 'entropy'}

# %% [markdown]
# ## Decision tree GridSearchCV

# %%
score_measure =   make_scorer(recall_score, average='micro')
kfolds = 5

param_grid = {
    'min_samples_split': np.arange(30,36),  
    'min_samples_leaf': np.arange(6,12),
    #'min_impurity_decrease': np.arange(0.0048, 0.0054, 0.0001),
    #'max_leaf_nodes': np.arange(162,168), 
    'max_depth': np.arange(15,21), 
    'criterion': ['entropy'],
    
}
dtree = DecisionTreeClassifier()
grid_search = GridSearchCV(estimator = dtree, param_grid=param_grid, cv=kfolds, 
                           scoring=score_measure, verbose=1, n_jobs=-1,  # n_jobs=-1 will utilize all available CPUs 
                           return_train_score=True)

dtGCV = grid_search.fit(X_train, y_train)

print(f"The best {score_measure} score is {grid_search.best_score_}")
print(f"... with parameters: {grid_search.best_params_}")

bestRecallTree = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# The best make_scorer(recall_score, average=micro) score is 0.908593678424187
# ... with parameters: {'criterion': 'entropy', 'max_depth': 18, 'min_samples_leaf': 6, 'min_samples_split': 30}

# %% [markdown]
# # SVC model

# %%
svm_lin_model = SVC(kernel="linear")
svmfit= svm_lin_model.fit(X_train,y_train)
y_pred_SVC=svmfit.predict(X_test)
# Out:
# C:\Users\rmura\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
c_matrix = confusion_matrix(y_test, y_pred_SVC)
TP = c_matrix[1][1]
TN = c_matrix[0][0]
FP = c_matrix[0][1]
FN = c_matrix[1][0]
performance = pd.concat([performance, pd.DataFrame({'model':"SVC", 
                                                    'Accuracy': [(TP+TN)/(TP+TN+FP+FN)], 
                                                    'Precision': [TP/(TP+FP)], 
                                                    'Recall': [TP/(TP+FN)], 
                                                    'F1': [2*TP/(2*TP+FP+FN)]
                                                     }, index=[0])])

# %% [markdown]
# ### SVC with different kernek in Gridsearch

# %%
# %%time
param_grid = {'C': [0.1, 1, 10, 50], 
              'gamma': [1, 0.1, 0.01, 0.001],
              'degree':[1,2,3],
              'kernel': ['linear','rbf','poly'],
              'degree':[2,3,4],
             } 
score_measure =   make_scorer(recall_score, average='micro')
kfolds = 3

SVC_grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
SVC_grid.fit(X_train,np.ravel( y_train))

print(SVC_grid.best_params_)
print(SVC_grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 1/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=1, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.240 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.236 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.234 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.231 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=1, kernel=rbf;, score=0.247 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.976 total time=   3.4s
# [CV 2/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   2.4s
# [CV 3/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.946 total time=   2.5s
# [CV 4/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   2.0s
# [CV 5/5] END C=0.1, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   5.7s
# [CV 1/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.1, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.685 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.953 total time=   0.6s
# [CV 2/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.949 total time=   0.4s
# [CV 3/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.956 total time=   0.4s
# [CV 4/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.936 total time=   0.5s
# [CV 5/5] END C=0.1, degree=2, gamma=0.1, kernel=poly;, score=0.936 total time=   0.4s
# [CV 1/5] END C=0.1, degree=2, gamma=0.01, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.01, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.01, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.01, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.01, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.01, kernel=rbf;, score=0.686 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.01, kernel=rbf;, score=0.678 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.01, kernel=rbf;, score=0.627 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.01, kernel=rbf;, score=0.668 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.01, kernel=poly;, score=0.865 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.01, kernel=poly;, score=0.838 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.01, kernel=poly;, score=0.844 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.01, kernel=poly;, score=0.820 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.01, kernel=poly;, score=0.831 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.001, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.001, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.001, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.001, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.001, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.001, kernel=rbf;, score=0.547 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.001, kernel=rbf;, score=0.581 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.001, kernel=rbf;, score=0.536 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.001, kernel=rbf;, score=0.532 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.001, kernel=rbf;, score=0.539 total time=   0.0s
# [CV 1/5] END C=0.1, degree=2, gamma=0.001, kernel=poly;, score=0.635 total time=   0.0s
# [CV 2/5] END C=0.1, degree=2, gamma=0.001, kernel=poly;, score=0.655 total time=   0.0s
# [CV 3/5] END C=0.1, degree=2, gamma=0.001, kernel=poly;, score=0.617 total time=   0.0s
# [CV 4/5] END C=0.1, degree=2, gamma=0.001, kernel=poly;, score=0.627 total time=   0.0s
# [CV 5/5] END C=0.1, degree=2, gamma=0.001, kernel=poly;, score=0.631 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=1, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.240 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.236 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.234 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.231 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=1, kernel=rbf;, score=0.247 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.963 total time=   3.0s
# [CV 2/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.949 total time=   2.2s
# [CV 3/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.959 total time=   2.6s
# [CV 4/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.939 total time=   2.7s
# [CV 5/5] END C=0.1, degree=3, gamma=1, kernel=poly;, score=0.942 total time=   2.9s
# [CV 1/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.1, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.685 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.963 total time=   3.3s
# [CV 2/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.2s
# [CV 3/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.956 total time=   2.9s
# [CV 4/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.1s
# [CV 5/5] END C=0.1, degree=3, gamma=0.1, kernel=poly;, score=0.939 total time=   3.5s
# [CV 1/5] END C=0.1, degree=3, gamma=0.01, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.01, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.01, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.01, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.01, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.01, kernel=rbf;, score=0.686 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.01, kernel=rbf;, score=0.678 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.01, kernel=rbf;, score=0.627 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.01, kernel=rbf;, score=0.668 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.01, kernel=poly;, score=0.932 total time=   0.6s
# [CV 2/5] END C=0.1, degree=3, gamma=0.01, kernel=poly;, score=0.939 total time=   0.4s
# [CV 3/5] END C=0.1, degree=3, gamma=0.01, kernel=poly;, score=0.932 total time=   0.5s
# [CV 4/5] END C=0.1, degree=3, gamma=0.01, kernel=poly;, score=0.929 total time=   0.4s
# [CV 5/5] END C=0.1, degree=3, gamma=0.01, kernel=poly;, score=0.922 total time=   0.4s
# [CV 1/5] END C=0.1, degree=3, gamma=0.001, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.001, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.001, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.001, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.001, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.001, kernel=rbf;, score=0.547 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.001, kernel=rbf;, score=0.581 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.001, kernel=rbf;, score=0.536 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.001, kernel=rbf;, score=0.532 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.001, kernel=rbf;, score=0.539 total time=   0.0s
# [CV 1/5] END C=0.1, degree=3, gamma=0.001, kernel=poly;, score=0.764 total time=   0.0s
# [CV 2/5] END C=0.1, degree=3, gamma=0.001, kernel=poly;, score=0.753 total time=   0.0s
# [CV 3/5] END C=0.1, degree=3, gamma=0.001, kernel=poly;, score=0.753 total time=   0.0s
# [CV 4/5] END C=0.1, degree=3, gamma=0.001, kernel=poly;, score=0.746 total time=   0.0s
# [CV 5/5] END C=0.1, degree=3, gamma=0.001, kernel=poly;, score=0.725 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=1, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=1, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=1, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=1, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=1, kernel=rbf;, score=0.240 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=1, kernel=rbf;, score=0.236 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=1, kernel=rbf;, score=0.234 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=1, kernel=rbf;, score=0.231 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=1, kernel=rbf;, score=0.247 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=1, kernel=poly;, score=0.959 total time=   3.0s
# [CV 2/5] END C=0.1, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   1.7s
# [CV 3/5] END C=0.1, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   2.5s
# [CV 4/5] END C=0.1, degree=4, gamma=1, kernel=poly;, score=0.936 total time=   2.0s
# [CV 5/5] END C=0.1, degree=4, gamma=1, kernel=poly;, score=0.946 total time=   3.2s
# [CV 1/5] END C=0.1, degree=4, gamma=0.1, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=0.1, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=0.1, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=0.1, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=0.1, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=0.1, kernel=rbf;, score=0.703 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=0.1, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=0.1, kernel=rbf;, score=0.685 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=0.1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=0.1, kernel=poly;, score=0.956 total time=   3.1s
# [CV 2/5] END C=0.1, degree=4, gamma=0.1, kernel=poly;, score=0.949 total time=   1.8s
# [CV 3/5] END C=0.1, degree=4, gamma=0.1, kernel=poly;, score=0.953 total time=   2.4s
# [CV 4/5] END C=0.1, degree=4, gamma=0.1, kernel=poly;, score=0.936 total time=   1.9s
# [CV 5/5] END C=0.1, degree=4, gamma=0.1, kernel=poly;, score=0.942 total time=   2.7s
# [CV 1/5] END C=0.1, degree=4, gamma=0.01, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=0.01, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=0.01, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=0.01, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=0.01, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=0.01, kernel=rbf;, score=0.686 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=0.01, kernel=rbf;, score=0.662 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=0.01, kernel=rbf;, score=0.678 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=0.01, kernel=rbf;, score=0.627 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=0.01, kernel=rbf;, score=0.668 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=0.01, kernel=poly;, score=0.956 total time=   4.1s
# [CV 2/5] END C=0.1, degree=4, gamma=0.01, kernel=poly;, score=0.949 total time=   1.6s
# [CV 3/5] END C=0.1, degree=4, gamma=0.01, kernel=poly;, score=0.953 total time=   2.7s
# [CV 4/5] END C=0.1, degree=4, gamma=0.01, kernel=poly;, score=0.936 total time=   2.1s
# [CV 5/5] END C=0.1, degree=4, gamma=0.01, kernel=poly;, score=0.942 total time=   2.6s
# [CV 1/5] END C=0.1, degree=4, gamma=0.001, kernel=linear;, score=0.848 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=0.001, kernel=linear;, score=0.814 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=0.001, kernel=linear;, score=0.817 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=0.001, kernel=linear;, score=0.797 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=0.001, kernel=linear;, score=0.824 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=0.001, kernel=rbf;, score=0.547 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=0.001, kernel=rbf;, score=0.581 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=0.001, kernel=rbf;, score=0.536 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=0.001, kernel=rbf;, score=0.532 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=0.001, kernel=rbf;, score=0.539 total time=   0.0s
# [CV 1/5] END C=0.1, degree=4, gamma=0.001, kernel=poly;, score=0.814 total time=   0.0s
# [CV 2/5] END C=0.1, degree=4, gamma=0.001, kernel=poly;, score=0.811 total time=   0.0s
# [CV 3/5] END C=0.1, degree=4, gamma=0.001, kernel=poly;, score=0.810 total time=   0.0s
# [CV 4/5] END C=0.1, degree=4, gamma=0.001, kernel=poly;, score=0.807 total time=   0.0s
# [CV 5/5] END C=0.1, degree=4, gamma=0.001, kernel=poly;, score=0.817 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=1, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=1, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=1, kernel=rbf;, score=0.713 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=1, kernel=rbf;, score=0.682 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=1, kernel=rbf;, score=0.668 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.980 total time=   3.1s
# [CV 2/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.949 total time=   5.9s
# [CV 3/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.946 total time=   2.2s
# [CV 4/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   2.0s
# [CV 5/5] END C=1, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   2.6s
# [CV 1/5] END C=1, degree=2, gamma=0.1, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.1, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=0.1, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.1, kernel=rbf;, score=0.889 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.1, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.970 total time=   1.5s
# [CV 2/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.946 total time=   1.4s
# [CV 3/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.953 total time=   1.4s
# [CV 4/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.956 total time=   1.0s
# [CV 5/5] END C=1, degree=2, gamma=0.1, kernel=poly;, score=0.949 total time=   2.1s
# [CV 1/5] END C=1, degree=2, gamma=0.01, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.01, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.01, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.01, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.01, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=0.01, kernel=rbf;, score=0.804 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.01, kernel=rbf;, score=0.787 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.01, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.01, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.01, kernel=rbf;, score=0.790 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.902 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.858 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.885 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.878 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.868 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=0.001, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.001, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.001, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.001, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.001, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=0.001, kernel=rbf;, score=0.676 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.001, kernel=rbf;, score=0.658 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.001, kernel=rbf;, score=0.627 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.001, kernel=rbf;, score=0.647 total time=   0.0s
# [CV 1/5] END C=1, degree=2, gamma=0.001, kernel=poly;, score=0.770 total time=   0.0s
# [CV 2/5] END C=1, degree=2, gamma=0.001, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END C=1, degree=2, gamma=0.001, kernel=poly;, score=0.746 total time=   0.0s
# [CV 4/5] END C=1, degree=2, gamma=0.001, kernel=poly;, score=0.739 total time=   0.0s
# [CV 5/5] END C=1, degree=2, gamma=0.001, kernel=poly;, score=0.739 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=1, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=1, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=1, kernel=rbf;, score=0.713 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=1, kernel=rbf;, score=0.682 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=1, kernel=rbf;, score=0.668 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.963 total time=   3.0s
# [CV 2/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.949 total time=   2.2s
# [CV 3/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.959 total time=   2.6s
# [CV 4/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.939 total time=   2.7s
# [CV 5/5] END C=1, degree=3, gamma=1, kernel=poly;, score=0.942 total time=   2.6s
# [CV 1/5] END C=1, degree=3, gamma=0.1, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=0.1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=0.1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=0.1, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=0.1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=0.1, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=0.1, kernel=rbf;, score=0.889 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=0.1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=0.1, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=0.1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.963 total time=   3.1s
# [CV 2/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.2s
# [CV 3/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.956 total time=   3.0s
# [CV 4/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.0s
# [CV 5/5] END C=1, degree=3, gamma=0.1, kernel=poly;, score=0.939 total time=   3.4s
# [CV 1/5] END C=1, degree=3, gamma=0.01, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=0.01, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=0.01, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=0.01, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=0.01, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=0.01, kernel=rbf;, score=0.804 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=0.01, kernel=rbf;, score=0.787 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=0.01, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=0.01, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=0.01, kernel=rbf;, score=0.790 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=0.01, kernel=poly;, score=0.963 total time=   1.6s
# [CV 2/5] END C=1, degree=3, gamma=0.01, kernel=poly;, score=0.946 total time=   1.5s
# [CV 3/5] END C=1, degree=3, gamma=0.01, kernel=poly;, score=0.959 total time=   2.1s
# [CV 4/5] END C=1, degree=3, gamma=0.01, kernel=poly;, score=0.949 total time=   1.2s
# [CV 5/5] END C=1, degree=3, gamma=0.01, kernel=poly;, score=0.946 total time=   2.4s
# [CV 1/5] END C=1, degree=3, gamma=0.001, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=0.001, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=0.001, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=0.001, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=0.001, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=0.001, kernel=rbf;, score=0.676 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=0.001, kernel=rbf;, score=0.658 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=0.001, kernel=rbf;, score=0.627 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=0.001, kernel=rbf;, score=0.647 total time=   0.0s
# [CV 1/5] END C=1, degree=3, gamma=0.001, kernel=poly;, score=0.845 total time=   0.0s
# [CV 2/5] END C=1, degree=3, gamma=0.001, kernel=poly;, score=0.818 total time=   0.0s
# [CV 3/5] END C=1, degree=3, gamma=0.001, kernel=poly;, score=0.837 total time=   0.0s
# [CV 4/5] END C=1, degree=3, gamma=0.001, kernel=poly;, score=0.827 total time=   0.0s
# [CV 5/5] END C=1, degree=3, gamma=0.001, kernel=poly;, score=0.824 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=1, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=1, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=1, kernel=rbf;, score=0.713 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=1, kernel=rbf;, score=0.682 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=1, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=1, kernel=rbf;, score=0.668 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=1, kernel=rbf;, score=0.732 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=1, kernel=poly;, score=0.959 total time=   3.1s
# [CV 2/5] END C=1, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   1.6s
# [CV 3/5] END C=1, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   2.4s
# [CV 4/5] END C=1, degree=4, gamma=1, kernel=poly;, score=0.936 total time=   1.9s
# [CV 5/5] END C=1, degree=4, gamma=1, kernel=poly;, score=0.946 total time=   3.1s
# [CV 1/5] END C=1, degree=4, gamma=0.1, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=0.1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=0.1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=0.1, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=0.1, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=0.1, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=0.1, kernel=rbf;, score=0.889 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=0.1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=0.1, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=0.1, kernel=rbf;, score=0.878 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=0.1, kernel=poly;, score=0.956 total time=   3.1s
# [CV 2/5] END C=1, degree=4, gamma=0.1, kernel=poly;, score=0.949 total time=   1.8s
# [CV 3/5] END C=1, degree=4, gamma=0.1, kernel=poly;, score=0.953 total time=   2.4s
# [CV 4/5] END C=1, degree=4, gamma=0.1, kernel=poly;, score=0.936 total time=   1.9s
# [CV 5/5] END C=1, degree=4, gamma=0.1, kernel=poly;, score=0.942 total time=   2.7s
# [CV 1/5] END C=1, degree=4, gamma=0.01, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=0.01, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=0.01, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=0.01, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=0.01, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=0.01, kernel=rbf;, score=0.804 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=0.01, kernel=rbf;, score=0.787 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=0.01, kernel=rbf;, score=0.780 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=0.01, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=0.01, kernel=rbf;, score=0.790 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=0.01, kernel=poly;, score=0.956 total time=   4.1s
# [CV 2/5] END C=1, degree=4, gamma=0.01, kernel=poly;, score=0.949 total time=   1.7s
# [CV 3/5] END C=1, degree=4, gamma=0.01, kernel=poly;, score=0.953 total time=   2.8s
# [CV 4/5] END C=1, degree=4, gamma=0.01, kernel=poly;, score=0.936 total time=   2.0s
# [CV 5/5] END C=1, degree=4, gamma=0.01, kernel=poly;, score=0.942 total time=   2.6s
# [CV 1/5] END C=1, degree=4, gamma=0.001, kernel=linear;, score=0.889 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=0.001, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=0.001, kernel=linear;, score=0.854 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=0.001, kernel=linear;, score=0.858 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=0.001, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=0.001, kernel=rbf;, score=0.676 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=0.001, kernel=rbf;, score=0.672 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=0.001, kernel=rbf;, score=0.658 total time=   0.0s
# [CV 4/5] END C=1, degree=4, gamma=0.001, kernel=rbf;, score=0.627 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=0.001, kernel=rbf;, score=0.647 total time=   0.0s
# [CV 1/5] END C=1, degree=4, gamma=0.001, kernel=poly;, score=0.878 total time=   0.0s
# [CV 2/5] END C=1, degree=4, gamma=0.001, kernel=poly;, score=0.851 total time=   0.0s
# [CV 3/5] END C=1, degree=4, gamma=0.001, kernel=poly;, score=0.868 total time=   0.1s
# [CV 4/5] END C=1, degree=4, gamma=0.001, kernel=poly;, score=0.878 total time=   0.0s
# [CV 5/5] END C=1, degree=4, gamma=0.001, kernel=poly;, score=0.847 total time=   0.0s
# [CV 1/5] END C=10, degree=2, gamma=1, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=2, gamma=1, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=2, gamma=1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=2, gamma=1, kernel=linear;, score=0.936 total time=   0.3s
# [CV 5/5] END C=10, degree=2, gamma=1, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=2, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 2/5] END C=10, degree=2, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 3/5] END C=10, degree=2, gamma=1, kernel=rbf;, score=0.719 total time=   0.0s
# [CV 4/5] END C=10, degree=2, gamma=1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 5/5] END C=10, degree=2, gamma=1, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 1/5] END C=10, degree=2, gamma=1, kernel=poly;, score=0.980 total time=   3.0s
# [CV 2/5] END C=10, degree=2, gamma=1, kernel=poly;, score=0.949 total time=   6.1s
# [CV 3/5] END C=10, degree=2, gamma=1, kernel=poly;, score=0.946 total time=   2.3s
# [CV 4/5] END C=10, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   2.0s
# [CV 5/5] END C=10, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   2.7s
# [CV 1/5] END C=10, degree=2, gamma=0.1, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=2, gamma=0.1, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=2, gamma=0.1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=2, gamma=0.1, kernel=linear;, score=0.936 total time=   0.2s
# [CV 5/5] END C=10, degree=2, gamma=0.1, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=2, gamma=0.1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END C=10, degree=2, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 3/5] END C=10, degree=2, gamma=0.1, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=10, degree=2, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END C=10, degree=2, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=10, degree=2, gamma=0.1, kernel=poly;, score=0.980 total time=   2.6s
# [CV 2/5] END C=10, degree=2, gamma=0.1, kernel=poly;, score=0.949 total time=   1.6s
# [CV 3/5] END C=10, degree=2, gamma=0.1, kernel=poly;, score=0.949 total time=   2.3s
# [CV 4/5] END C=10, degree=2, gamma=0.1, kernel=poly;, score=0.956 total time=   2.6s
# [CV 5/5] END C=10, degree=2, gamma=0.1, kernel=poly;, score=0.953 total time=   3.5s
# [CV 1/5] END C=10, degree=2, gamma=0.01, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=2, gamma=0.01, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=2, gamma=0.01, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=2, gamma=0.01, kernel=linear;, score=0.936 total time=   0.2s
# [CV 5/5] END C=10, degree=2, gamma=0.01, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=2, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END C=10, degree=2, gamma=0.01, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 3/5] END C=10, degree=2, gamma=0.01, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 4/5] END C=10, degree=2, gamma=0.01, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 5/5] END C=10, degree=2, gamma=0.01, kernel=rbf;, score=0.888 total time=   0.0s
# [CV 1/5] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.953 total time=   0.7s
# [CV 2/5] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.949 total time=   0.4s
# [CV 3/5] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.956 total time=   0.4s
# [CV 4/5] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.936 total time=   0.4s
# [CV 5/5] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.936 total time=   0.3s
# [CV 1/5] END C=10, degree=2, gamma=0.001, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=2, gamma=0.001, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=2, gamma=0.001, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=2, gamma=0.001, kernel=linear;, score=0.936 total time=   0.3s
# [CV 5/5] END C=10, degree=2, gamma=0.001, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=2, gamma=0.001, kernel=rbf;, score=0.814 total time=   0.0s
# [CV 2/5] END C=10, degree=2, gamma=0.001, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 3/5] END C=10, degree=2, gamma=0.001, kernel=rbf;, score=0.793 total time=   0.0s
# [CV 4/5] END C=10, degree=2, gamma=0.001, kernel=rbf;, score=0.753 total time=   0.0s
# [CV 5/5] END C=10, degree=2, gamma=0.001, kernel=rbf;, score=0.759 total time=   0.0s
# [CV 1/5] END C=10, degree=2, gamma=0.001, kernel=poly;, score=0.865 total time=   0.0s
# [CV 2/5] END C=10, degree=2, gamma=0.001, kernel=poly;, score=0.838 total time=   0.0s
# [CV 3/5] END C=10, degree=2, gamma=0.001, kernel=poly;, score=0.844 total time=   0.0s
# [CV 4/5] END C=10, degree=2, gamma=0.001, kernel=poly;, score=0.820 total time=   0.0s
# [CV 5/5] END C=10, degree=2, gamma=0.001, kernel=poly;, score=0.831 total time=   0.0s
# [CV 1/5] END C=10, degree=3, gamma=1, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=3, gamma=1, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=3, gamma=1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=3, gamma=1, kernel=linear;, score=0.936 total time=   0.3s
# [CV 5/5] END C=10, degree=3, gamma=1, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=3, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 2/5] END C=10, degree=3, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 3/5] END C=10, degree=3, gamma=1, kernel=rbf;, score=0.719 total time=   0.0s
# [CV 4/5] END C=10, degree=3, gamma=1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 5/5] END C=10, degree=3, gamma=1, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 1/5] END C=10, degree=3, gamma=1, kernel=poly;, score=0.963 total time=   2.9s
# [CV 2/5] END C=10, degree=3, gamma=1, kernel=poly;, score=0.949 total time=   2.2s
# [CV 3/5] END C=10, degree=3, gamma=1, kernel=poly;, score=0.959 total time=   2.5s
# [CV 4/5] END C=10, degree=3, gamma=1, kernel=poly;, score=0.939 total time=   2.6s
# [CV 5/5] END C=10, degree=3, gamma=1, kernel=poly;, score=0.942 total time=   2.7s
# [CV 1/5] END C=10, degree=3, gamma=0.1, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=3, gamma=0.1, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=3, gamma=0.1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=3, gamma=0.1, kernel=linear;, score=0.936 total time=   0.2s
# [CV 5/5] END C=10, degree=3, gamma=0.1, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=3, gamma=0.1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END C=10, degree=3, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 3/5] END C=10, degree=3, gamma=0.1, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=10, degree=3, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END C=10, degree=3, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=10, degree=3, gamma=0.1, kernel=poly;, score=0.963 total time=   3.2s
# [CV 2/5] END C=10, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.2s
# [CV 3/5] END C=10, degree=3, gamma=0.1, kernel=poly;, score=0.956 total time=   2.8s
# [CV 4/5] END C=10, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.0s
# [CV 5/5] END C=10, degree=3, gamma=0.1, kernel=poly;, score=0.939 total time=   3.4s
# [CV 1/5] END C=10, degree=3, gamma=0.01, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=3, gamma=0.01, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=3, gamma=0.01, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=3, gamma=0.01, kernel=linear;, score=0.936 total time=   0.2s
# [CV 5/5] END C=10, degree=3, gamma=0.01, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=3, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END C=10, degree=3, gamma=0.01, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 3/5] END C=10, degree=3, gamma=0.01, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 4/5] END C=10, degree=3, gamma=0.01, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 5/5] END C=10, degree=3, gamma=0.01, kernel=rbf;, score=0.888 total time=   0.0s
# [CV 1/5] END C=10, degree=3, gamma=0.01, kernel=poly;, score=0.963 total time=   3.1s
# [CV 2/5] END C=10, degree=3, gamma=0.01, kernel=poly;, score=0.943 total time=   2.1s
# [CV 3/5] END C=10, degree=3, gamma=0.01, kernel=poly;, score=0.959 total time=   2.8s
# [CV 4/5] END C=10, degree=3, gamma=0.01, kernel=poly;, score=0.942 total time=   1.9s
# [CV 5/5] END C=10, degree=3, gamma=0.01, kernel=poly;, score=0.939 total time=   3.3s
# [CV 1/5] END C=10, degree=3, gamma=0.001, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=3, gamma=0.001, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=3, gamma=0.001, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=3, gamma=0.001, kernel=linear;, score=0.936 total time=   0.3s
# [CV 5/5] END C=10, degree=3, gamma=0.001, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=3, gamma=0.001, kernel=rbf;, score=0.814 total time=   0.0s
# [CV 2/5] END C=10, degree=3, gamma=0.001, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 3/5] END C=10, degree=3, gamma=0.001, kernel=rbf;, score=0.793 total time=   0.0s
# [CV 4/5] END C=10, degree=3, gamma=0.001, kernel=rbf;, score=0.753 total time=   0.0s
# [CV 5/5] END C=10, degree=3, gamma=0.001, kernel=rbf;, score=0.759 total time=   0.0s
# [CV 1/5] END C=10, degree=3, gamma=0.001, kernel=poly;, score=0.895 total time=   0.0s
# [CV 2/5] END C=10, degree=3, gamma=0.001, kernel=poly;, score=0.865 total time=   0.0s
# [CV 3/5] END C=10, degree=3, gamma=0.001, kernel=poly;, score=0.878 total time=   0.0s
# [CV 4/5] END C=10, degree=3, gamma=0.001, kernel=poly;, score=0.881 total time=   0.0s
# [CV 5/5] END C=10, degree=3, gamma=0.001, kernel=poly;, score=0.861 total time=   0.0s
# [CV 1/5] END C=10, degree=4, gamma=1, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=4, gamma=1, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=4, gamma=1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=4, gamma=1, kernel=linear;, score=0.936 total time=   0.3s
# [CV 5/5] END C=10, degree=4, gamma=1, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=4, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 2/5] END C=10, degree=4, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 3/5] END C=10, degree=4, gamma=1, kernel=rbf;, score=0.719 total time=   0.0s
# [CV 4/5] END C=10, degree=4, gamma=1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 5/5] END C=10, degree=4, gamma=1, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 1/5] END C=10, degree=4, gamma=1, kernel=poly;, score=0.959 total time=   2.9s
# [CV 2/5] END C=10, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   1.6s
# [CV 3/5] END C=10, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   2.4s
# [CV 4/5] END C=10, degree=4, gamma=1, kernel=poly;, score=0.936 total time=   1.9s
# [CV 5/5] END C=10, degree=4, gamma=1, kernel=poly;, score=0.946 total time=   3.2s
# [CV 1/5] END C=10, degree=4, gamma=0.1, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=4, gamma=0.1, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=4, gamma=0.1, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=4, gamma=0.1, kernel=linear;, score=0.936 total time=   0.2s
# [CV 5/5] END C=10, degree=4, gamma=0.1, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=4, gamma=0.1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END C=10, degree=4, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 3/5] END C=10, degree=4, gamma=0.1, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=10, degree=4, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END C=10, degree=4, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=0.956 total time=   3.0s
# [CV 2/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=0.949 total time=   1.8s
# [CV 3/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=0.953 total time=   2.3s
# [CV 4/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=0.936 total time=   1.9s
# [CV 5/5] END C=10, degree=4, gamma=0.1, kernel=poly;, score=0.942 total time=   2.6s
# [CV 1/5] END C=10, degree=4, gamma=0.01, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=4, gamma=0.01, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=4, gamma=0.01, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=4, gamma=0.01, kernel=linear;, score=0.936 total time=   0.3s
# [CV 5/5] END C=10, degree=4, gamma=0.01, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=4, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END C=10, degree=4, gamma=0.01, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 3/5] END C=10, degree=4, gamma=0.01, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 4/5] END C=10, degree=4, gamma=0.01, kernel=rbf;, score=0.925 total time=   0.0s
# [CV 5/5] END C=10, degree=4, gamma=0.01, kernel=rbf;, score=0.888 total time=   0.0s
# [CV 1/5] END C=10, degree=4, gamma=0.01, kernel=poly;, score=0.956 total time=   4.0s
# [CV 2/5] END C=10, degree=4, gamma=0.01, kernel=poly;, score=0.949 total time=   1.6s
# [CV 3/5] END C=10, degree=4, gamma=0.01, kernel=poly;, score=0.953 total time=   2.7s
# [CV 4/5] END C=10, degree=4, gamma=0.01, kernel=poly;, score=0.936 total time=   1.9s
# [CV 5/5] END C=10, degree=4, gamma=0.01, kernel=poly;, score=0.942 total time=   2.5s
# [CV 1/5] END C=10, degree=4, gamma=0.001, kernel=linear;, score=0.956 total time=   0.2s
# [CV 2/5] END C=10, degree=4, gamma=0.001, kernel=linear;, score=0.943 total time=   0.2s
# [CV 3/5] END C=10, degree=4, gamma=0.001, kernel=linear;, score=0.929 total time=   0.2s
# [CV 4/5] END C=10, degree=4, gamma=0.001, kernel=linear;, score=0.936 total time=   0.2s
# [CV 5/5] END C=10, degree=4, gamma=0.001, kernel=linear;, score=0.936 total time=   0.1s
# [CV 1/5] END C=10, degree=4, gamma=0.001, kernel=rbf;, score=0.814 total time=   0.0s
# [CV 2/5] END C=10, degree=4, gamma=0.001, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 3/5] END C=10, degree=4, gamma=0.001, kernel=rbf;, score=0.793 total time=   0.0s
# [CV 4/5] END C=10, degree=4, gamma=0.001, kernel=rbf;, score=0.753 total time=   0.0s
# [CV 5/5] END C=10, degree=4, gamma=0.001, kernel=rbf;, score=0.759 total time=   0.0s
# [CV 1/5] END C=10, degree=4, gamma=0.001, kernel=poly;, score=0.919 total time=   0.6s
# [CV 2/5] END C=10, degree=4, gamma=0.001, kernel=poly;, score=0.905 total time=   0.5s
# [CV 3/5] END C=10, degree=4, gamma=0.001, kernel=poly;, score=0.925 total time=   0.5s
# [CV 4/5] END C=10, degree=4, gamma=0.001, kernel=poly;, score=0.932 total time=   0.5s
# [CV 5/5] END C=10, degree=4, gamma=0.001, kernel=poly;, score=0.919 total time=   0.4s
# [CV 1/5] END C=50, degree=2, gamma=1, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=2, gamma=1, kernel=linear;, score=0.966 total time=   0.5s
# [CV 3/5] END C=50, degree=2, gamma=1, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=2, gamma=1, kernel=linear;, score=0.953 total time=   0.6s
# [CV 5/5] END C=50, degree=2, gamma=1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=2, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 2/5] END C=50, degree=2, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 3/5] END C=50, degree=2, gamma=1, kernel=rbf;, score=0.719 total time=   0.0s
# [CV 4/5] END C=50, degree=2, gamma=1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 5/5] END C=50, degree=2, gamma=1, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 1/5] END C=50, degree=2, gamma=1, kernel=poly;, score=0.980 total time=   2.9s
# [CV 2/5] END C=50, degree=2, gamma=1, kernel=poly;, score=0.949 total time=   5.8s
# [CV 3/5] END C=50, degree=2, gamma=1, kernel=poly;, score=0.946 total time=   2.2s
# [CV 4/5] END C=50, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   1.9s
# [CV 5/5] END C=50, degree=2, gamma=1, kernel=poly;, score=0.953 total time=   2.5s
# [CV 1/5] END C=50, degree=2, gamma=0.1, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=2, gamma=0.1, kernel=linear;, score=0.966 total time=   0.4s
# [CV 3/5] END C=50, degree=2, gamma=0.1, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=2, gamma=0.1, kernel=linear;, score=0.953 total time=   0.6s
# [CV 5/5] END C=50, degree=2, gamma=0.1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=2, gamma=0.1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END C=50, degree=2, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 3/5] END C=50, degree=2, gamma=0.1, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=50, degree=2, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END C=50, degree=2, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=50, degree=2, gamma=0.1, kernel=poly;, score=0.980 total time=   2.6s
# [CV 2/5] END C=50, degree=2, gamma=0.1, kernel=poly;, score=0.949 total time=   1.7s
# [CV 3/5] END C=50, degree=2, gamma=0.1, kernel=poly;, score=0.949 total time=   1.9s
# [CV 4/5] END C=50, degree=2, gamma=0.1, kernel=poly;, score=0.956 total time=   2.7s
# [CV 5/5] END C=50, degree=2, gamma=0.1, kernel=poly;, score=0.953 total time=   3.8s
# [CV 1/5] END C=50, degree=2, gamma=0.01, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=2, gamma=0.01, kernel=linear;, score=0.966 total time=   0.4s
# [CV 3/5] END C=50, degree=2, gamma=0.01, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=2, gamma=0.01, kernel=linear;, score=0.953 total time=   0.6s
# [CV 5/5] END C=50, degree=2, gamma=0.01, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=2, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END C=50, degree=2, gamma=0.01, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 3/5] END C=50, degree=2, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END C=50, degree=2, gamma=0.01, kernel=rbf;, score=0.932 total time=   0.0s
# [CV 5/5] END C=50, degree=2, gamma=0.01, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=50, degree=2, gamma=0.01, kernel=poly;, score=0.966 total time=   1.4s
# [CV 2/5] END C=50, degree=2, gamma=0.01, kernel=poly;, score=0.953 total time=   0.8s
# [CV 3/5] END C=50, degree=2, gamma=0.01, kernel=poly;, score=0.969 total time=   1.1s
# [CV 4/5] END C=50, degree=2, gamma=0.01, kernel=poly;, score=0.953 total time=   1.0s
# [CV 5/5] END C=50, degree=2, gamma=0.01, kernel=poly;, score=0.946 total time=   1.1s
# [CV 1/5] END C=50, degree=2, gamma=0.001, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=2, gamma=0.001, kernel=linear;, score=0.966 total time=   0.5s
# [CV 3/5] END C=50, degree=2, gamma=0.001, kernel=linear;, score=0.949 total time=   0.7s
# [CV 4/5] END C=50, degree=2, gamma=0.001, kernel=linear;, score=0.953 total time=   0.7s
# [CV 5/5] END C=50, degree=2, gamma=0.001, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=2, gamma=0.001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 2/5] END C=50, degree=2, gamma=0.001, kernel=rbf;, score=0.845 total time=   0.0s
# [CV 3/5] END C=50, degree=2, gamma=0.001, kernel=rbf;, score=0.847 total time=   0.0s
# [CV 4/5] END C=50, degree=2, gamma=0.001, kernel=rbf;, score=0.847 total time=   0.0s
# [CV 5/5] END C=50, degree=2, gamma=0.001, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 1/5] END C=50, degree=2, gamma=0.001, kernel=poly;, score=0.882 total time=   0.0s
# [CV 2/5] END C=50, degree=2, gamma=0.001, kernel=poly;, score=0.845 total time=   0.0s
# [CV 3/5] END C=50, degree=2, gamma=0.001, kernel=poly;, score=0.854 total time=   0.0s
# [CV 4/5] END C=50, degree=2, gamma=0.001, kernel=poly;, score=0.854 total time=   0.0s
# [CV 5/5] END C=50, degree=2, gamma=0.001, kernel=poly;, score=0.841 total time=   0.0s
# [CV 1/5] END C=50, degree=3, gamma=1, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=3, gamma=1, kernel=linear;, score=0.966 total time=   0.4s
# [CV 3/5] END C=50, degree=3, gamma=1, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=3, gamma=1, kernel=linear;, score=0.953 total time=   0.6s
# [CV 5/5] END C=50, degree=3, gamma=1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=3, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 2/5] END C=50, degree=3, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 3/5] END C=50, degree=3, gamma=1, kernel=rbf;, score=0.719 total time=   0.0s
# [CV 4/5] END C=50, degree=3, gamma=1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 5/5] END C=50, degree=3, gamma=1, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 1/5] END C=50, degree=3, gamma=1, kernel=poly;, score=0.963 total time=   2.8s
# [CV 2/5] END C=50, degree=3, gamma=1, kernel=poly;, score=0.949 total time=   2.2s
# [CV 3/5] END C=50, degree=3, gamma=1, kernel=poly;, score=0.959 total time=   2.6s
# [CV 4/5] END C=50, degree=3, gamma=1, kernel=poly;, score=0.939 total time=   2.6s
# [CV 5/5] END C=50, degree=3, gamma=1, kernel=poly;, score=0.942 total time=   2.7s
# [CV 1/5] END C=50, degree=3, gamma=0.1, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=3, gamma=0.1, kernel=linear;, score=0.966 total time=   0.4s
# [CV 3/5] END C=50, degree=3, gamma=0.1, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=3, gamma=0.1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 5/5] END C=50, degree=3, gamma=0.1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=3, gamma=0.1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END C=50, degree=3, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 3/5] END C=50, degree=3, gamma=0.1, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=50, degree=3, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END C=50, degree=3, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=50, degree=3, gamma=0.1, kernel=poly;, score=0.963 total time=   3.2s
# [CV 2/5] END C=50, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.2s
# [CV 3/5] END C=50, degree=3, gamma=0.1, kernel=poly;, score=0.956 total time=   2.8s
# [CV 4/5] END C=50, degree=3, gamma=0.1, kernel=poly;, score=0.946 total time=   2.1s
# [CV 5/5] END C=50, degree=3, gamma=0.1, kernel=poly;, score=0.939 total time=   3.3s
# [CV 1/5] END C=50, degree=3, gamma=0.01, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=3, gamma=0.01, kernel=linear;, score=0.966 total time=   0.5s
# [CV 3/5] END C=50, degree=3, gamma=0.01, kernel=linear;, score=0.949 total time=   0.7s
# [CV 4/5] END C=50, degree=3, gamma=0.01, kernel=linear;, score=0.953 total time=   0.7s
# [CV 5/5] END C=50, degree=3, gamma=0.01, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=3, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END C=50, degree=3, gamma=0.01, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 3/5] END C=50, degree=3, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END C=50, degree=3, gamma=0.01, kernel=rbf;, score=0.932 total time=   0.0s
# [CV 5/5] END C=50, degree=3, gamma=0.01, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=50, degree=3, gamma=0.01, kernel=poly;, score=0.963 total time=   3.3s
# [CV 2/5] END C=50, degree=3, gamma=0.01, kernel=poly;, score=0.943 total time=   2.2s
# [CV 3/5] END C=50, degree=3, gamma=0.01, kernel=poly;, score=0.959 total time=   2.8s
# [CV 4/5] END C=50, degree=3, gamma=0.01, kernel=poly;, score=0.942 total time=   1.9s
# [CV 5/5] END C=50, degree=3, gamma=0.01, kernel=poly;, score=0.939 total time=   3.2s
# [CV 1/5] END C=50, degree=3, gamma=0.001, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=3, gamma=0.001, kernel=linear;, score=0.966 total time=   0.5s
# [CV 3/5] END C=50, degree=3, gamma=0.001, kernel=linear;, score=0.949 total time=   0.7s
# [CV 4/5] END C=50, degree=3, gamma=0.001, kernel=linear;, score=0.953 total time=   0.7s
# [CV 5/5] END C=50, degree=3, gamma=0.001, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=3, gamma=0.001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 2/5] END C=50, degree=3, gamma=0.001, kernel=rbf;, score=0.845 total time=   0.0s
# [CV 3/5] END C=50, degree=3, gamma=0.001, kernel=rbf;, score=0.847 total time=   0.0s
# [CV 4/5] END C=50, degree=3, gamma=0.001, kernel=rbf;, score=0.847 total time=   0.0s
# [CV 5/5] END C=50, degree=3, gamma=0.001, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 1/5] END C=50, degree=3, gamma=0.001, kernel=poly;, score=0.926 total time=   0.3s
# [CV 2/5] END C=50, degree=3, gamma=0.001, kernel=poly;, score=0.916 total time=   0.2s
# [CV 3/5] END C=50, degree=3, gamma=0.001, kernel=poly;, score=0.919 total time=   0.2s
# [CV 4/5] END C=50, degree=3, gamma=0.001, kernel=poly;, score=0.908 total time=   0.3s
# [CV 5/5] END C=50, degree=3, gamma=0.001, kernel=poly;, score=0.902 total time=   0.2s
# [CV 1/5] END C=50, degree=4, gamma=1, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=4, gamma=1, kernel=linear;, score=0.966 total time=   0.5s
# [CV 3/5] END C=50, degree=4, gamma=1, kernel=linear;, score=0.949 total time=   0.7s
# [CV 4/5] END C=50, degree=4, gamma=1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 5/5] END C=50, degree=4, gamma=1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=4, gamma=1, kernel=rbf;, score=0.750 total time=   0.0s
# [CV 2/5] END C=50, degree=4, gamma=1, kernel=rbf;, score=0.716 total time=   0.0s
# [CV 3/5] END C=50, degree=4, gamma=1, kernel=rbf;, score=0.719 total time=   0.0s
# [CV 4/5] END C=50, degree=4, gamma=1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 5/5] END C=50, degree=4, gamma=1, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 1/5] END C=50, degree=4, gamma=1, kernel=poly;, score=0.959 total time=   3.0s
# [CV 2/5] END C=50, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   1.6s
# [CV 3/5] END C=50, degree=4, gamma=1, kernel=poly;, score=0.953 total time=   2.5s
# [CV 4/5] END C=50, degree=4, gamma=1, kernel=poly;, score=0.936 total time=   2.0s
# [CV 5/5] END C=50, degree=4, gamma=1, kernel=poly;, score=0.946 total time=   3.0s
# [CV 1/5] END C=50, degree=4, gamma=0.1, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=4, gamma=0.1, kernel=linear;, score=0.966 total time=   0.4s
# [CV 3/5] END C=50, degree=4, gamma=0.1, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=4, gamma=0.1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 5/5] END C=50, degree=4, gamma=0.1, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=4, gamma=0.1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END C=50, degree=4, gamma=0.1, kernel=rbf;, score=0.916 total time=   0.0s
# [CV 3/5] END C=50, degree=4, gamma=0.1, kernel=rbf;, score=0.892 total time=   0.0s
# [CV 4/5] END C=50, degree=4, gamma=0.1, kernel=rbf;, score=0.953 total time=   0.0s
# [CV 5/5] END C=50, degree=4, gamma=0.1, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=50, degree=4, gamma=0.1, kernel=poly;, score=0.956 total time=   3.1s
# [CV 2/5] END C=50, degree=4, gamma=0.1, kernel=poly;, score=0.949 total time=   1.8s
# [CV 3/5] END C=50, degree=4, gamma=0.1, kernel=poly;, score=0.953 total time=   2.4s
# [CV 4/5] END C=50, degree=4, gamma=0.1, kernel=poly;, score=0.936 total time=   1.9s
# [CV 5/5] END C=50, degree=4, gamma=0.1, kernel=poly;, score=0.942 total time=   2.7s
# [CV 1/5] END C=50, degree=4, gamma=0.01, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=4, gamma=0.01, kernel=linear;, score=0.966 total time=   0.5s
# [CV 3/5] END C=50, degree=4, gamma=0.01, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=4, gamma=0.01, kernel=linear;, score=0.953 total time=   0.7s
# [CV 5/5] END C=50, degree=4, gamma=0.01, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=4, gamma=0.01, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 2/5] END C=50, degree=4, gamma=0.01, kernel=rbf;, score=0.899 total time=   0.0s
# [CV 3/5] END C=50, degree=4, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 4/5] END C=50, degree=4, gamma=0.01, kernel=rbf;, score=0.932 total time=   0.0s
# [CV 5/5] END C=50, degree=4, gamma=0.01, kernel=rbf;, score=0.915 total time=   0.0s
# [CV 1/5] END C=50, degree=4, gamma=0.01, kernel=poly;, score=0.956 total time=   4.0s
# [CV 2/5] END C=50, degree=4, gamma=0.01, kernel=poly;, score=0.949 total time=   1.7s
# [CV 3/5] END C=50, degree=4, gamma=0.01, kernel=poly;, score=0.953 total time=   2.7s
# [CV 4/5] END C=50, degree=4, gamma=0.01, kernel=poly;, score=0.936 total time=   2.0s
# [CV 5/5] END C=50, degree=4, gamma=0.01, kernel=poly;, score=0.942 total time=   2.6s
# [CV 1/5] END C=50, degree=4, gamma=0.001, kernel=linear;, score=0.966 total time=   1.1s
# [CV 2/5] END C=50, degree=4, gamma=0.001, kernel=linear;, score=0.966 total time=   0.4s
# [CV 3/5] END C=50, degree=4, gamma=0.001, kernel=linear;, score=0.949 total time=   0.6s
# [CV 4/5] END C=50, degree=4, gamma=0.001, kernel=linear;, score=0.953 total time=   0.6s
# [CV 5/5] END C=50, degree=4, gamma=0.001, kernel=linear;, score=0.953 total time=   0.7s
# [CV 1/5] END C=50, degree=4, gamma=0.001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 2/5] END C=50, degree=4, gamma=0.001, kernel=rbf;, score=0.845 total time=   0.0s
# [CV 3/5] END C=50, degree=4, gamma=0.001, kernel=rbf;, score=0.847 total time=   0.0s
# [CV 4/5] END C=50, degree=4, gamma=0.001, kernel=rbf;, score=0.847 total time=   0.0s
# [CV 5/5] END C=50, degree=4, gamma=0.001, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 1/5] END C=50, degree=4, gamma=0.001, kernel=poly;, score=0.943 total time=   1.3s
# [CV 2/5] END C=50, degree=4, gamma=0.001, kernel=poly;, score=0.929 total time=   0.7s
# [CV 3/5] END C=50, degree=4, gamma=0.001, kernel=poly;, score=0.953 total time=   1.4s
# [CV 4/5] END C=50, degree=4, gamma=0.001, kernel=poly;, score=0.942 total time=   1.0s
# [CV 5/5] END C=50, degree=4, gamma=0.001, kernel=poly;, score=0.939 total time=   0.9s
# {'C': 50, 'degree': 2, 'gamma': 0.01, 'kernel': 'poly'}
# SVC(C=50, degree=2, gamma=0.01, kernel='poly')
# Wall time: 8min 35s

# %%
performance
# Out:
#    model  Accuracy  Precision    Recall        F1
# 0     LR  0.921569   0.948718  0.902439  0.925000
# 0  dtree  0.925466   0.912088  0.954023  0.932584
# 0    SVC  0.885714   0.907895  0.884615  0.896104

# %% [markdown]
# # Analysis
# - One of the major Health  problems is Obesity on world as per WHO
# - The purpose the process is to dedicate the obesity and level of obesity.
# - For this purpose we selected UCI Oobesity data https://archive.ics.uci.edu/ml/datasets/Estimation+of+obesity+levels+based+on+eating+habits+and+physical+condition+#
# - We selected Logistic regression Classfication,SVC, dtree.
# - from performance table we can say that dtree is giving the best score based on recall .95
# - dtree i good model for this process
