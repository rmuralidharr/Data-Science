# %% [markdown]
# # Predictive Modeling Example

# %% [markdown]
# ## Step 1: Import the libraries we will use in this notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

np.random.seed(1) # set this to ensure the results are repeatable.

# %% [markdown]
# ## Step 2: Load the given data that we will model

# %%
df = pd.read_csv('~/Murali/DSP/Week 2/c02_dataset_3_1.csv')

df.head(3)
# Out:
#     input     target
# 0  116.24  23.127310
# 1   93.88 -15.156104
# 2   94.72  44.973376

# %% [markdown]
# Seperate out the input m(X) and the target (y)

# %%
X=df[['input']]
y=df[['target']]

# %% [markdown]
# ## Step 3: Explore the given data
#
# Often we will do much more than this, but at least look at things using a scatterplot

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Fit the model
#
# Fit the linear regression model to the dataset

# %%
lin_reg=LinearRegression()
_ = lin_reg.fit(np.sin(X),y)

# OR, we could combine the two lines above to one as follows...
#lin_reg = LinearRegression().fit(X,y)

# %% [markdown]
# ## Step 5: Analyze the linear regression model's performance

# %% [markdown]
# Visualize the linear regression model results

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')
ax.scatter(X,lin_reg.predict(np.sin(X)),color='blue')

ax.set_title('Linear Regression')
ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %%
b0 = lin_reg.intercept_[0]
b1 = lin_reg.coef_[0][0]
r2 = lin_reg.score(X, y)
print(f"Y = {b0:.2f} + {b1:.2f}sin(x)")
print(f"R^2: {lin_reg.score(np.sin(X), y):.3f}")
# Out:
# Y = 25.35 + 31.12sin(x)
# R^2: 0.762

# %% [markdown]
# ## First copy
#
# ## Original model without error
# - Y = 20.03 + 30.55sin(x)
# - R^2: 0.998
#
# ## After adding normal distribution with mean=5 & std =12 ( added error in target variable)
# - Y = 25.35 + 31.12sin(x)
# -  R^2: 0.762
#
# ## From original model without error r Square value is .99 & with error in data set we got
# - based on r Square value (r2 is only metrics we have to check model perfomenaces in this notebook).
# - original data r2 value is greater than  > error data set. so original data model is good based on r Square.
# - the coefficient value changed after the data changes.
#
# ## In real world the r2 square is near to 1 then we call it overfit model, but the data we generated in "c02 model 3 data gen" is toy data. In toy data r2 square is neear to 1 then we say its good model.
# - In real data set 0.5 < R^2 < 0.7 approximately
